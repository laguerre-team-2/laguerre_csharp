# %% [markdown]
# ## Звіт про виконання командного практичного завдання: імплементації проекту Лагера на мові C#

# %% [markdown]
# #### Опис: Був розроблений проект на C#, дані для візуалізації записуються у відповідні файли формату csv і візуалізуються в Jupyter Notebook:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display
# %matplotlib ipympl

# %% [markdown]
# ### Табульовані дані значення функції Лагера при певних $n_i$ в точці після якої значення всіх поліномів < N далі менші за ε
#
# код з C#:
#
# ![carbon1.png](attachment:77bc3268-c8c9-4a45-9fbe-9273560c2fb4.png)

# %%
tabulatedExperiment = pd.read_csv("data/tabulatedExperiment.csv")
tabulatedExperiment
# Out:
#             t   n          L(t)
# 0   43.543544   0  2.456458e-19
# 1   43.543544   1 -4.253951e-17
# 2   43.543544   2  3.640710e-15
# 3   43.543544   3 -2.052763e-13
# 4   43.543544   4  8.576494e-12
# 5   43.543544   5 -2.831588e-10
# 6   43.543544   6  7.693555e-09
# 7   43.543544   7 -1.769005e-07
# 8   43.543544   8  3.513017e-06
# 9   43.543544   9 -6.119337e-05
# 10  43.543544  10  9.464013e-04

# %% [markdown]
# ### Табульовані дані коефіціентів трансформації Лагера
#
# код з C#:
#
# ![carbon2.png](attachment:df8b8f36-2af0-4816-959f-066c133f73d6.png)

# %%
tabulateLaguerreTransformation = pd.read_csv("data/tabulateLaguerreTransformation.csv")

fig1, ax1 = plt.subplots(figsize=(10, 6))
ax1.bar(tabulateLaguerreTransformation['x'], tabulateLaguerreTransformation['t'], color='skyblue')
ax1.set_xlabel('x')
ax1.set_ylabel('t')
ax1.set_title('Коефіцієнти трансформації Лагера')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Графіки поліномів різних степенів функції Лагера
#
# код з C#:
#
# ![carbon3.png](attachment:8fdb23c5-1f49-4e33-8894-a7245d522a01.png)

# %%
lauguerreFuncData = pd.read_csv("data/lauguerreFuncData.csv")
function_names = lauguerreFuncData.columns[1:]

fig2, ax2 = plt.subplots(figsize=(10, 6))
for function_name in lauguerreFuncData.columns[1:]:
    ax2.plot(lauguerreFuncData['x'], lauguerreFuncData[function_name], label=function_name)
ax2.set_title("Plot of Laguerre function")
ax2.set_xlabel("x")
ax2.set_ylabel("y")
ax2.legend(title="Function")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Графіки обернених трансформації Лагера для іменних функцій учасників команди
#
# код з C#:
#
#
# ![carbon4.png](attachment:df3f3d65-84a5-4969-b357-83af52666a92.png)

# %%
reverseTransformationData = pd.read_csv("data/reverseTransformationData.csv")
columns = reverseTransformationData.columns

function_names = [col for col in columns if col != 'x']

num_functions = len(function_names) // 2

fig, axs = plt.subplots(num_functions, 1, figsize=(10, 5*num_functions))

for i in range(num_functions):
    idx = i * 2
    func_name = function_names[idx].split("_")[0]
    transformed_name = function_names[idx + 1]

    axs[i].plot(reverseTransformationData['x'], reverseTransformationData[function_names[idx]], label="Function")
    axs[i].plot(reverseTransformationData['x'], reverseTransformationData[transformed_name], label="Reverse laguerre transformation", linestyle='--')
    axs[i].set_title(f'{func_name[4:]}\'s function')
    axs[i].legend()

plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Графіки обернених трансформації Лагера функції Гаусса з різними параметрами μ і λ
#
# код з C#:
# ![carbon5.png](attachment:3062068c-1a79-4322-9a91-821765078f98.png)

# %%
GaussReverseTransformationData = pd.read_csv("data/GaussReverseTransformationData.csv")
columns = GaussReverseTransformationData.columns

function_names = [col for col in columns if col != 'x']
function_names
num_functions = len(function_names) // 2

fig, axs = plt.subplots(num_functions, 1, figsize=(10, 5*num_functions))

for i in range(num_functions):
    idx = i * 2
    func_name = function_names[idx].split("_")[0]
    transformed_name = function_names[idx + 1]

    axs[i].plot(GaussReverseTransformationData['x'], GaussReverseTransformationData[function_names[idx]], label="Function")
    axs[i].plot(GaussReverseTransformationData['x'], GaussReverseTransformationData[transformed_name], label="Reverse laguerre transformation", linestyle='--')
    axs[i].set_title(f'{func_name} function')
    axs[i].legend()

plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
